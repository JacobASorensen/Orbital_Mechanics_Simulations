# %%
import numpy as np
from matplotlib import pyplot as plt

# theta

PI = np.pi

theta = np.arange(0, 2*PI, 0.01)

theta_2 = np.arange(-PI*2/3 + 0.001, PI * 2/3 - 0.001,0.01 )

#

r_1 = 1/ (1 + (0) * np.cos(theta)) # e = 0
r_2 = 1/ (1 + (0.5) * np.cos(theta)) # e = 0.5
r_3 = 1/ (1 + (0.7) * np.cos(theta)) # e = 0.9


r_4 = 1/ (1 + (1.5) * np.cos(theta_2)) # e = 1.5
# r_5 = 1/ (1 + (1.5) * np.cos(theta_2)) # e = 2
# r_6 = 1/ (1 + (1.5) * np.cos(theta_2)) # e = 2

plt.figure(figsize=(6,6))
plt.polar( theta, r_1)
plt.polar( theta, r_2)
plt.polar( theta, r_3)
plt.polar( theta_2, r_4)
# plt.polar( theta, r_5)
# plt.polar( theta, r_6)
